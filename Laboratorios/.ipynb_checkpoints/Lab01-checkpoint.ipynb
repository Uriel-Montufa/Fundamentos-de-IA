# %% [markdown]
# ## Laboratorio 1
# # 01/09/2026
# # Alumno

# %%
print("Mi primer sistema inteligente")
nombre = input("Escribe su nombre, empezando por apellido paterno")
matricula = input("Escribe tu matricula")
promedio = float(input("Escribe tu promedio"))
# Out:
# Mi primer sistema inteligente
# Escribe su nombre, empezando por apellido paterno Uriel Montufa Palacios
# Escribe tu matricula 20243L601050
# Escribe tu promedio 9

# %%
print ("Datos almacenados")
print ("Nombre: ", nombre)
print ("Matricula: ", matricula)
print ("Promedio: ", promedio)
# Out:
# Datos almacenados
# Nombre:  Uriel Montufa Palacios
# Matricula:  20243L601050
# Promedio:  9.0

# %%
# Reglas
if promedio>=8.0 and promedio<=10:
    print("Excelente desempeño")
elif promedio<8.0 and promedio>=7.0:
    print("Echale ganas, puedes mejorar")
elif promedio<7.0 and promedio>=6.0:
    print("Necesitas ayuda")
else:
    print("Reprobaste, ve a recursa")
# Out:
# Excelente desempeño
